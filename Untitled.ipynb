# %%
#Мак Кормак Условие 1

import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
dx = 1
n = [1,3,1,3,1,3,1,3]
teta =[0.3,0.6,1, 0.3,0.6,1,0.3,0.6]
c = []
m = str(teta)
dt = 1
u = np.zeros(((41,18,8)))
u1 = np.zeros(((41,18,8)))
for k in range (1,7):
    for i in range (0,40):
        u [i][0][k] =math.sin((2*3.14*n[k]*i)/40) 
for i in range (0,7):   
    k = (dx*teta[i])/dt
    c.append(k)
for k in range (1,7):
    for i in range (1,40):
        for j in range (0,17):
            u1 [i][j+1][k] = u[i][j][k] - c[k]*(dt/dx)*(u[i+1][j][k]-u[i][j][k])
            u[i][j+1][k] =  1/2*(u[i][j][k]+u1 [i][j+1][k]-c[k]*(dt/dx)*(u1[i][j+1][k]-u1[i-1][j+1][k]))

    
for k in range (1,7):
    plt.subplot(3,3,k)
    plt.gca().set_title('n='+str(n[k])+'teta ='+str(teta[k]))
    plt.plot(u[:,-1,k])
#Мак Кормак Условие 2

import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
dx = 1
n = [1,3,1,3,1,3,1,3]
teta =[0.3,0.6,1, 0.3,0.6,1,0.3,0.6]
c = []
m = 41
dt = 1
u = np.zeros(((41,18,8)))
u1 = np.zeros(((41,18,8)))
for k in range (0,7):
    for i in range (0,int(m-1)):
        if i <= 10:
            u[i][0][k] = 1
        else:
            u[i][0][k] = 0
for i in range (0,7):   
    k = (dx*teta[i])/dt
    c.append(k)
for k in range (1,7):
    for i in range (1,40):
        for j in range (0,17):
            u1[i][j+1][k] = u[i][j][k] - c[k]*(dt/dx)*(u[i+1][j][k]-u[i][j][k])
            u[i][j+1][k] =  1/2*(u[i][j][k]+u1[i][j+1][k]-c[k]*(dt/dx)*(u1[i][j+1][k]-u1[i-1][j+1][k]))

    
for k in range (1,7):
    plt.subplot(3,3,k)
    plt.gca().set_title('n='+str(n[k])+'teta ='+str(teta[k]))
    plt.plot(u[:,-1,k])

# %%
#Мак кормак условие 3

import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
dx = 1
n = [1,3,1,3,1,3,1,3]
teta =[0.3,0.6,1, 0.3,0.6,1,0.3,0.6]
c = []
m = 41
dt = 1
u = np.zeros(((41,18,8)))
u1 = np.zeros(((41,18,8)))
for k in range (0,7):
    for i in range (0,int(m-1)):
        if i <= 10:
            u[i][0][k] = 0
        else:
            u[i][0][k] = 1
for i in range (0,7):   
    k = (dx*teta[i])/dt
    c.append(k)
for k in range (1,7):
    for i in range (1,40):
        for j in range (0,17):
            u1 [i][j+1][k] = u[i][j][k] - c[k]*(dt/dx)*(u[i+1][j][k]-u[i][j][k])
            u[i][j+1][k] =  1/2*(u[i][j][k]+u1 [i][j][k]-c[k]*(u1[i][j][k]-u1[i-1][j][k]))

    
for k in range (1,7):
    plt.subplot(3,3,k)
    plt.gca().set_title('n='+str(n[k])+'teta ='+str(teta[k]))
    plt.plot(u[:,-1,k])

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
dx = 1
m = 41
n = [1,3,1,3,1,3,1,3]
teta =[0.3,0.6,1, 0.3,0.6,1,0.3,0.6]
c = []
t = np.linspace(0,18,1000)
#m = str(teta)
dt = 1
u = np.zeros(((m,18,8)))
for k in range (0,7):
    for i in range (0,m-1):
        if i <= 10:
            u[i][0][k] = 0
        else:
            u[i][0][k] = 1
        
for i in range (0,7):   
    k = (dx*teta[i])/dt
    c.append(k)
v = teta   
for k in range (0,7):
    for i in range (0,m-1):
        for j in range (0,17):
            u[i][j+1][k] = u [i][j][k]- teta [k] * (u[i][j][k]-u[i-1][j][k])+(1/2)*v[k]*(v[k]-1)*(u[i][j][k]-2*u[i-1][j][k]+u[i-2][j][k])
            
    
for k in range (1,7):
    plt.subplot(3,3,k)
    plt.gca().set_title('n='+str(n[k])+'teta ='+str(teta[k]))
    plt.plot(u[:,-1,k])

# %%
#Теение 1
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
dx = 1
m = 41
n = [1,3,1,3,1,3,1,3]
teta =[0.3,0.6,1, 0.3,0.6,1,0.3,0.6]
c = []
t = np.linspace(0,18,1000)
#m = str(teta)
dt = 1
u = np.zeros(((m,18,8)))
for k in range (1,7):
    for i in range (0,40):
        u [i][0][k] =math.sin((2*3.14*n[k]*i)/40) 
for i in range (0,7):   
    k = (dx*teta[i])/dt
    c.append(k)
v = teta   
for k in range (0,7):
    for i in range (0,m-1):
        for j in range (0,17):
           u[i][j+1][k] = u [i][j][k]- teta [k] * (u[i][j][k]-u[i-1][j][k])+(1/2)*v[k]*(v[k]-1)*(u[i][j][k]-2*u[i-1][j][k]+u[i-2][j][k])
           
    
for k in range (1,7):
    plt.subplot(3,3,k)
    plt.gca().set_title('n='+str(n[k])+'teta ='+str(teta[k]))
    plt.plot(u[:,0,k])

# %%
#Течение 2

import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
dx = 1
m = 41
n = [1,3,1,3,1,3,1,3]
teta =[0.3,0.6,1, 0.3,0.6,1,0.3,0.6]
c = []
t = np.linspace(0,18,1000)
#m = str(teta)
dt = 1
u = np.zeros(((m,18,8)))
for k in range (0,7):
    for i in range (0,m-1):
        if i <= 10:
            u[i][0][k] = 1
        else:
            u[i][0][k] = 0
for i in range (0,7):   
    k = (dx*teta[i])/dt
    c.append(k)
v = teta   
for k in range (0,7):
    for i in range (0,m-1):
        for j in range (0,17):
            u[i][j+1][k] = u [i][j][k]- teta [k] * (u[i][j][k]-u[i-1][j][k])+(1/2)*v[k]*(v[k]-1)*(u[i][j][k]-2*u[i-1][j][k]+u[i-2][j][k])
      
    
for k in range (1,7):
    plt.subplot(3,3,k)
    plt.gca().set_title('n='+str(n[k])+'teta ='+str(teta[k]))
    plt.plot(u[:,-1,k])

# %%
#Течение 3

import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
dx = 1
m = 41
n = [1,3,1,3,1,3,1,3]
teta =[0.3,0.6,1, 0.3,0.6,1,0.3,0.6]
c = []
#t = np.linspace(0,18,1000)
#m = str(teta)
dt = 1
u = np.zeros(((m,18,8)))
for k in range (0,7):
    for i in range (0,m-1):
        if i <= 10:
            u[i][0][k] = 0
        else:
            u[i][0][k] = 1

        
        
for i in range (0,7):   
    k = (dx*teta[i])/dt
    c.append(k)
    
for k in range (0,7):
    for i in range (0,m-1):
        for j in range (0,17):
            u[i][j+1][k] = u [i][j][k]- teta [k] * (u[i][j][k]-u[i-1][j][k])+(1/2)*v[k]*(v[k]-1)*(u[i][j][k]-2*u[i-1][j][k]+u[i-2][j][k])
      
    
for k in range (1,7):я
    plt.subplot(3,3,k)
    plt.gca().set_title('n='+str(n[k])+'teta ='+str(teta[k]))
    plt.plot(u[:,-1,k])
